# %%
from MakeLightcurves import *
# Out:
# lk version: 1.0b30

# %%
for tic in set([tic for tic in crossmatch_planets['TIC']]):
    print(tic)
# Out:
# 366443426
# 366528389
# 435339847
# 146799150
# 69747919
# 366410512
# 12822545
# 366576758
# 242961495
# 366568760
# 7020254

# %%
plot_lc(tic=366443426)
# Out:
# Fetching TPF...
# Detrending...
# Success

# %%
plot_lc(tic=366528389)
# Out:
# Fetching TPF...
# Detrending...
# Success

# %%
plot_lc(tic=435339847)
# I haven't looked into what's up with this one
# Out:
# Fetching TPF...
# Detrending...
# Success

# %%
plot_lc(tic=146799150)
# Out:
# Fetching TPF...
# Detrending...
# Success

# %%
plot_lc(tic=69747919)
# Out:
# Fetching TPF...
# Detrending...
# Success

# %%
plot_lc(tic=366410512)
# Out:
# Fetching TPF...
# Detrending...
# Success

# %%
plot_lc(tic=12822545)
# Out:
# Fetching TPF...
# Detrending...
# Success

# %%
plot_lc(tic=366576758)
# Out:
# Fetching TPF...
# Detrending...
# Success

# %%
plot_lc(tic=242961495)
# Same with this; haven't looked into it
# Out:
# Fetching TPF...
# No data found for target "242961495".
# Detrending...
# /Users/charlotte/anaconda3/lib/python3.5/site-packages/lightkurve/search.py:133: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-4fcda7fec1fe> in <module>()
# ----> 1 plot_lc(tic=242961495)
#
# /Users/charlotte/Dropbox (MIT)/Code/tess_k2_overlap/MakeLightcurves.py in plot_lc(lc, tic, epic, hostname, mission, transits, verbose)
#     150
#     151     if lc == None:
# --> 152         lc = make_lc(tic=tic,epic=epic,hostname=hostname,mission=mission,verbose=verbose)
#     153
#     154     if hostname:
#
# /Users/charlotte/Dropbox (MIT)/Code/tess_k2_overlap/MakeLightcurves.py in make_lc(tic, epic, hostname, mission, verbose)
#     124     if verbose: print('Detrending...')
# ...

# %%
plot_lc(tic=366568760)
# Out:
# Fetching TPF...
# Detrending...
# Success

# %%
plot_lc(tic=7020254)
# Out:
# Fetching TPF...
# Detrending...
# Success
