# %%
from MakeLightcurves import *
from parameters import *
# Out:
# lk version: 1.0b30

# %%
plot_lc(tic=69747919,mission='tess')
plot_lc(tic=69747919,mission='k2')

# %%
predict_transits(hostname='K2-167',mission='tess',verbose=True)
# Out:
# Fetching planet parameters...
# Predicting transits...
# Success
# [2458356.8291580174, 2458366.8066390175, 2458376.7841200177]

# %%
period, t0, dur, depth, impact_param, r_planet, r_star = get_params('K2-167')

# %%
predict_transits(hostname='K2-167',mission='tess',period=period,t0=t0,verbose=True)
# Out:
# Predicting transits...
# Success
# [2458356.8291580174, 2458366.8066390175, 2458376.7841200177]
